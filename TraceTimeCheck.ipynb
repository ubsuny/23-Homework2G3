# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedCode99/TraceOfArrayCode/blob/main/TraceTimeCheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time

mat = [[2,1,1],[1,3,1],[1,1,4]] # Insert a square matrix


rows,columns = np.shape(mat) # Save the number of rows and columns

if  rows == columns:

  t0 = time.time()
  trace = np.einsum('ii', mat) # Calculating Trace Using EinSum
  print("Trace Using EinSum = ", trace)
  t1 = time.time()

  t2 = time.time()
  trace = np.trace(mat) # Calculating Trace Using NumPy
  print("Trace Using NumPy = ", trace)
  t3 = time.time()

  t4 = time.time()
  trace = sum(mat[i][i] for i in range(len(mat))) # Calculating Trace Using List Comprehension
  print("Trace Using List Comprehension = ", trace)
  t5 = time.time()


  #Calculating Trace using For Loop
  t6 = time.time()
  trace = 0
  for j in range(len(mat)):
    trace = trace + mat[j][j]
  print("Trace Using For Loop = ", trace)
  t7 = time.time()


  #Calculating Trace using While Loop

  t8 = time.time()
  trace = 0
  i=0

  while i < len(mat):
    trace = trace + mat[i][i]
    i=i+1

  print("Trace Using While Loop = ", trace)
  t9 = time.time()


  # Calculating Trace using SymPy

  from sympy import Matrix

  t10 = time.time()
  matrix = Matrix(mat)

  trace = matrix.trace()

  print("Trace Using SymPy = ", trace)
  t11 = time.time()

else:
    print("The Matrix You Inserted Is Not Square. The Trace Operator is Only Defined For Square Matrices. Please Insert A Square Matrix")


method = ["EinSum","NumPy","List\nComprehension",
          "For Loop", "While Loop","SymPy"] # List of Methods Used

dt = [t1-t0, t3-t2, t5-t4, t7-t6, t9-t8, t11-t10] # Time it took for each method

import matplotlib.pyplot as plt

# Plotting Results

# Create a bar graph
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
plt.bar(method, dt)

# Adding labels and title
plt.xlabel('Method')
plt.ylabel('Time (s)')
plt.title('Execution Time of a Program Calculating 3x3 Matrix')

# Display the plot
plt.show()
# Out:
# Trace Using EinSum =  9
# Trace Using NumPy =  9
# Trace Using List Comprehension =  9
# Trace Using For Loop =  9
# Trace Using While Loop =  9
# Trace Using SymPy =  9

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C', 'Category D']
values = [15, 24, 8, 12]

# Create a bar graph
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
plt.bar(method, dt)

# Adding labels and title
plt.xlabel('Method')
plt.ylabel('Time (s)')
plt.title('Execution Time of a Program Calculating 3x3 Matrix')

# Display the plot
plt.show()
